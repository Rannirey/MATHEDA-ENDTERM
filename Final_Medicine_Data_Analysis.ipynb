# %% [markdown]
# # Medicine Data Analysis
#
# ### Name: Ranni Rey I. Guadalupe
# ### Section: BSCPE 2-A

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
medicine_path = "medicine.csv"
df_medicine = pd.read_csv(medicine_path, encoding="utf-8")
df_medicine.head()
df = pd.read_csv(medicine_path)

# %%
medicine_path = "medicine.csv"
df_medicine = pd.read_csv(medicine_path, encoding="utf-8")
df_medicine.head()
# Out:
#    brand id brand name        type                                   slug  \
# 0      4077     A-Cold  allopathic                    a-coldsyrup4-mg5-ml
# 1      4006      A-Cof  allopathic         a-cofsyrup10-mg30-mg125-mg5-ml
# 2      6174     A-Clox  allopathic              a-cloxinjection500-mgvial
# 3      6173     A-Clox  allopathic              a-cloxinjection250-mgvial
# 4      6172     A-Clox  allopathic  a-cloxpowder-for-suspension125-mg5-ml
#
#              dosage form                                            generic  \
# 0                  Syrup                           Bromhexine Hydrochloride
# 1                  Syrup  Dextromethorphan + Pseudoephedrine + Triprolidine
# 2              Injection                                 Cloxacillin Sodium
# 3              Injection                                 Cloxacillin Sodium
# 4  Powder for Suspension                                 Cloxacillin Sodium
#
#                      strength            manufacturer  \
# ...

# %%
# Data Cleaning
# Filling missing numerical values with the mean
num_cols = df_medicine.select_dtypes(include=[np.number]).columns
df_medicine[num_cols] = df_medicine[num_cols].fillna(df_medicine[num_cols].mean())

# Filling missing categorical values with the most frequent value (mode)
cat_cols = df_medicine.select_dtypes(include=[object]).columns
df_medicine[cat_cols] = df_medicine[cat_cols].fillna(df_medicine[cat_cols].mode().iloc[0])

# Removing duplicates
df_medicine = df_medicine.drop_duplicates()
df_medicine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21714 entries, 0 to 21713
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand id           21714 non-null  int64
#  1   brand name         21714 non-null  object
#  2   type               21714 non-null  object
#  3   slug               21714 non-null  object
#  4   dosage form        21714 non-null  object
#  5   generic            21714 non-null  object
#  6   strength           21714 non-null  object
#  7   manufacturer       21714 non-null  object
#  8   package container  21714 non-null  object
#  9   package_size       21714 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# # Distribution Of Medicine Types

# %%
plt.figure(figsize=(10, 5))
df['type'].value_counts().plot(kind='bar', color='royalblue')
plt.title("Distribution of Medicine Types")
plt.xlabel("Medicine Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Top 10 Manufacturers

# %%
plt.figure(figsize=(10, 5))
df['manufacturer'].value_counts().head(10).plot(kind='bar', color='purple')
plt.title("Top 10 Manufacturers by Number of Medicines")
plt.xlabel("Manufacturer")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bottom 10 Manufacturers

# %%
plt.figure(figsize=(10, 5))
df['manufacturer'].value_counts().tail(10).plot(kind='bar', color='brown')
plt.title("Bottom 10 Manufacturers by Number of Medicines")
plt.xlabel("Manufacturer")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Top Medicine Strengths by Frequency

# %%
plt.figure(figsize=(10, 5))
df['strength'].value_counts().head(10).plot(kind='bar', color='orange')
plt.title("Top 10 Most Common Strengths of Medicines")
plt.xlabel("Strength")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Top 10 Generic Medicine

# %%
plt.figure(figsize=(10, 5))
df['generic'].value_counts().head(10).plot(kind='bar', color='navy')
plt.title("Top 10 Generic Medicines")
plt.xlabel("Generic Name")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bottom 10 Generic Medicine

# %%
plt.figure(figsize=(10, 5))
df['generic'].value_counts().tail(10).plot(kind='bar', color='maroon')
plt.title("Bottom 10 Generic Medicines")
plt.xlabel("Generic Name")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #  Top 10 Most Common Dosage Forms

# %%
plt.figure(figsize=(10, 5))
df['dosage form'].value_counts().head(10).plot(kind='bar', color='seagreen')
plt.title("Top 10 Common Dosage Forms")
plt.xlabel("Dosage Form")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bottom 10 Dosage Forms

# %%
plt.figure(figsize=(10, 5))
df['dosage form'].value_counts().tail(10).plot(kind='bar', color='darkred')
plt.title("Bottom 10 Common Dosage Forms")
plt.xlabel("Dosage Form")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Trends in Package Sizes

# %%
plt.figure(figsize=(10, 5))
df['package_size'].value_counts().head(10).plot(kind='bar', color='darkblue')
plt.title("Top 10 Most Common Package Sizes")
plt.xlabel("Package Size")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\johnf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2547 (\N{BENGALI RUPEE SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\johnf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Trends in Package Containers

# %%
plt.figure(figsize=(10, 5))
df['package container'].value_counts().head(10).plot(kind='bar', color='darkgreen')
plt.title("Top 10 Most Common Package Containers")
plt.xlabel("Package Container")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\johnf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2547 (\N{BENGALI RUPEE SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\johnf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Strength vs Package Size

# %%
plt.figure(figsize=(10, 5))
strength_counts = df['strength'].value_counts()
package_size_counts = df['package_size'].value_counts()
common_strengths = df[df['strength'].isin(strength_counts.index[:20])]
plt.scatter(common_strengths['strength'], common_strengths['package_size'].apply(lambda x: package_size_counts.get(x, 0)), color='teal', alpha=0.5)
plt.title("Scatter Plot of Strength vs. Package Size Frequency")
plt.xlabel("Strength")
plt.ylabel("Package Size Frequency")
plt.xticks(rotation=45)
plt.show()
